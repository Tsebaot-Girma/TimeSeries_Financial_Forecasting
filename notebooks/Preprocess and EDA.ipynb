# %%
# %load_ext autoreload

# %%
# %autoreload 2

# %%
# Import necessary libraries

import pandas as pd
import os
import sys
sys.path.append("../scripts/")

from data_cleaning import clean_data
from data_extraction import fetch_data
from eda import visualize_data, calculate_daily_change
from volatility_analysis import analyze_volatility

# %%
# Step 1: Data Extraction

# Define parameters
TICKERS = ['TSLA', 'BND', 'SPY']
START_DATE = '2015-01-01'
END_DATE = '2025-01-31'

# Fetch historical financial data
historical_data = fetch_data(TICKERS, START_DATE, END_DATE)
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed

# %%
# Display the first few rows for each ticker
for ticker, df in historical_data.items():
    print(f"\nData for {ticker}:")
    print(df.head())
# Out:
# Data for TSLA:
# Price           Close       High        Low       Open    Volume
# Ticker           TSLA       TSLA       TSLA       TSLA      TSLA
# Date
# 2015-01-02  14.620667  14.883333  14.217333  14.858000  71466000
# 2015-01-05  14.006000  14.433333  13.810667  14.303333  80527500
# 2015-01-06  14.085333  14.280000  13.614000  14.004000  93928500
# 2015-01-07  14.063333  14.318667  13.985333  14.223333  44526000
# 2015-01-08  14.041333  14.253333  14.000667  14.187333  51637500
#
# Data for BND:
# Price           Close       High        Low       Open   Volume
# Ticker            BND        BND        BND        BND      BND
# Date
# 2015-01-02  62.573116  62.603400  62.398984  62.406557  2218800
# 2015-01-05  62.754841  62.777553  62.610993  62.641277  5820100
# 2015-01-06  62.936558  63.125829  62.860850  62.860850  3887600
# 2015-01-07  62.974388  63.050096  62.875969  62.944104  2433400
# 2015-01-08  62.875957  62.921381  62.815389  62.921381  1873400
#
# Data for SPY:
# ...

# %%
# Step 2: Data Cleaning

# Clean the data
cleaned_data = clean_data(historical_data)
# Out:
# Data types for TSLA:
# Price   Ticker
# Close   TSLA      float64
# High    TSLA      float64
# Low     TSLA      float64
# Open    TSLA      float64
# Volume  TSLA        int64
# dtype: object
# Missing values for TSLA:
# Price   Ticker
# Close   TSLA      0
# High    TSLA      0
# Low     TSLA      0
# Open    TSLA      0
# Volume  TSLA      0
# dtype: int64
# c:\Users\Tsebaot\Desktop\week 11\TimeSeries_Financial_Forecasting\notebooks\../scripts\data_cleaning.py:8: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   ticker_data.fillna(method='ffill', inplace=True)
# Data types for BND:
# Price   Ticker
# Close   BND       float64
# High    BND       float64
# Low     BND       float64
# Open    BND       float64
# Volume  BND         int64
# dtype: object
# Missing values for BND:
# Price   Ticker
# Close   BND       0
# High    BND       0
# Low     BND       0
# Open    BND       0
# ...

# %%
# Step 3: Exploratory Data Analysis (EDA)

# Visualize the cleaned data
visualize_data(cleaned_data)

# Calculate and plot daily percentage change
calculate_daily_change(cleaned_data)

# %%
# Step 4: Volatility Analysis

# Analyze volatility
analyze_volatility(cleaned_data)
# Out:
# Outliers for TSLA:
# Price          Close        High         Low        Open     Volume  \
# Ticker          TSLA        TSLA        TSLA        TSLA       TSLA
# Date
# 2020-02-03 -0.565180   52.409332   44.901333   44.912666  705975000
# 2020-02-04 -0.503920   64.599335   55.591999   58.863998  914082000
# 2020-02-05 -0.591101   56.398666   46.940666   54.883999  726357000
# 2020-02-27 -0.622973   49.318001   44.599998   48.666668  364158000
# 2020-06-10 -0.424962   68.498665   65.500000   66.125336  278451000
# ...              ...         ...         ...         ...        ...
# 2024-11-11  1.992577  358.640015  336.000000  346.299988  210521600
# 2024-12-18  2.766171  488.540009  427.010010  466.500000  149340800
# 2024-12-24  2.956286  462.779999  435.140015  435.899994   59551800
# 2025-01-03  2.511339  411.880005  379.450012  381.480011   95423300
# 2025-01-15  2.663946  429.799988  405.660004  409.899994   81375500
#
# Price      Daily Change Rolling Mean Rolling Std
# ...
